# %%
import cv2 # OpenCVはcv2という名称で扱われる
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('misc/4.2.05.tiff')
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
cv2.imwrite('misc/airplane.jpg', img)
# Out:
# True
